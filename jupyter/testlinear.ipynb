# %% [markdown]
# # Lab 1 Analysis Example using Thicket

# %%
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
# # jupyter
# tk = th.Thicket.from_caliperreader(glob("/home/stevenm27/435Project/caliper/cpu_mpi/naive/*.cali", recursive=True))

# local
parallel = 'cpu_linear'

# GLOBAL VARS
process_cols = (1,)
df_linear = pd.DataFrame()
df_strassen = pd.DataFrame()

for algo in ('naive', 'recursion'):
    tk = th.Thicket.from_caliperreader(glob(f"../caliper/{parallel}/{algo}/*.cali", recursive=True))

    gb = tk.groupby("num_procs")

    ctk = th.Thicket.concat_thickets(
        thickets=list(gb.values()),
        headers=list(gb.keys()),
        axis="columns",
        metadata_key="InputSize"
    )
    
    print(ctk.dataframe)
    
    if algo == 'naive':
        df_linear = ctk.dataframe
    else:
        df_strassen = ctk.dataframe
    
df_linear
# Out:
# 1  thickets created...
# {1: <thicket.thicket.Thicket object at 0x00000256E98BC910>}
#                                                               1  \
#                                                             nid
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              128         1
#                                                   256         1
#                                                   512         1
#                                                   1024        1
#                                                   2048        1
#                                                   4096        1
# {'name': 'comp', 'type': 'function'}              128         3
#                                                   256         3
#                                                   512         3
#                                                   1024        3
#                                                   2048        3
#                                                   4096        3
# {'name': 'comp_large', 'type': 'function'}        128         4
#                                                   256         4
#                                                   512         4
#                                                   1024        4
#                                                   2048        4
#                                                   4096        4
# {'name': 'correctness_check', 'type': 'function'} 128         5
#                                                   256         5
#                                                   512         5
#                                                   1024        5
#                                                   2048        5
#                                                   4096        5
# {'name': 'data_init', 'type': 'function'}         128         2
#                                                   256         2
#                                                   512         2
#                                                   1024        2
#                                                   2048        2
#                                                   4096        2
#
#                                                                             \
#                                                               spot.channel
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              128        regionprofile
#                                                   256        regionprofile
#                                                   512        regionprofile
#                                                   1024       regionprofile
#                                                   2048       regionprofile
#                                                   4096       regionprofile
# {'name': 'comp', 'type': 'function'}              128        regionprofile
#                                                   256        regionprofile
#                                                   512        regionprofile
#                                                   1024       regionprofile
#                                                   2048       regionprofile
#                                                   4096       regionprofile
# {'name': 'comp_large', 'type': 'function'}        128        regionprofile
#                                                   256        regionprofile
#                                                   512        regionprofile
#                                                   1024       regionprofile
#                                                   2048       regionprofile
#                                                   4096       regionprofile
# {'name': 'correctness_check', 'type': 'function'} 128        regionprofile
#                                                   256        regionprofile
#                                                   512        regionprofile
#                                                   1024       regionprofile
#                                                   2048       regionprofile
#                                                   4096       regionprofile
# {'name': 'data_init', 'type': 'function'}         128        regionprofile
#                                                   256        regionprofile
#                                                   512        regionprofile
#                                                   1024       regionprofile
#                                                   2048       regionprofile
#                                                   4096       regionprofile
#
#                                                                            \
#                                                             Min time/rank
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              128            0.045358
#                                                   256            0.357011
#                                                   512            3.300747
#                                                   1024          34.874304
#                                                   2048         323.149891
#                                                   4096        2619.881903
# {'name': 'comp', 'type': 'function'}              128            0.021761
#                                                   256            0.176096
#                                                   512            1.638055
#                                                   1024          17.957615
#                                                   2048         161.343535
#                                                   4096        1309.023555
# {'name': 'comp_large', 'type': 'function'}        128            0.021748
#                                                   256            0.176072
#                                                   512            1.638023
#                                                   1024          17.957571
#                                                   2048         161.343488
#                                                   4096        1308.997267
# {'name': 'correctness_check', 'type': 'function'} 128            0.022043
#                                                   256            0.177356
#                                                   512            1.645814
#                                                   1024          16.870409
#                                                   2048         161.630269
#                                                   4096        1308.476825
# {'name': 'data_init', 'type': 'function'}         128            0.000629
#                                                   256            0.002410
#                                                   512            0.012849
#                                                   1024           0.037916
#                                                   2048           0.150541
#                                                   4096           0.599948
#
#                                                                            \
#                                                             Max time/rank
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              128            0.045358
#                                                   256            0.357011
#                                                   512            3.300747
#                                                   1024          34.874304
#                                                   2048         323.149891
#                                                   4096        2619.881903
# {'name': 'comp', 'type': 'function'}              128            0.021761
#                                                   256            0.176096
#                                                   512            1.638055
#                                                   1024          17.957615
#                                                   2048         161.343535
#                                                   4096        1309.023555
# {'name': 'comp_large', 'type': 'function'}        128            0.021748
#                                                   256            0.176072
#                                                   512            1.638023
#                                                   1024          17.957571
#                                                   2048         161.343488
#                                                   4096        1308.997267
# {'name': 'correctness_check', 'type': 'function'} 128            0.022043
#                                                   256            0.177356
#                                                   512            1.645814
#                                                   1024          16.870409
#                                                   2048         161.630269
#                                                   4096        1308.476825
# {'name': 'data_init', 'type': 'function'}         128            0.000629
#                                                   256            0.002410
#                                                   512            0.012849
#                                                   1024           0.037916
#                                                   2048           0.150541
#                                                   4096           0.599948
#
#                                                                            \
#                                                             Avg time/rank
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              128            0.045358
#                                                   256            0.357011
#                                                   512            3.300747
#                                                   1024          34.874304
#                                                   2048         323.149891
#                                                   4096        2619.881903
# {'name': 'comp', 'type': 'function'}              128            0.021761
#                                                   256            0.176096
#                                                   512            1.638055
#                                                   1024          17.957615
#                                                   2048         161.343535
#                                                   4096        1309.023555
# {'name': 'comp_large', 'type': 'function'}        128            0.021748
#                                                   256            0.176072
#                                                   512            1.638023
#                                                   1024          17.957571
#                                                   2048         161.343488
#                                                   4096        1308.997267
# {'name': 'correctness_check', 'type': 'function'} 128            0.022043
#                                                   256            0.177356
#                                                   512            1.645814
#                                                   1024          16.870409
#                                                   2048         161.630269
#                                                   4096        1308.476825
# {'name': 'data_init', 'type': 'function'}         128            0.000629
#                                                   256            0.002410
#                                                   512            0.012849
#                                                   1024           0.037916
#                                                   2048           0.150541
#                                                   4096           0.599948
#
#                                                                           \
#                                                               Total time
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              128           0.045358
#                                                   256           0.357011
#                                                   512           3.300747
#                                                   1024         34.874304
#                                                   2048        323.149891
#                                                   4096       2619.881903
# {'name': 'comp', 'type': 'function'}              128           0.021761
#                                                   256           0.176096
#                                                   512           1.638055
#                                                   1024         17.957615
#                                                   2048        161.343535
#                                                   4096       1309.023555
# {'name': 'comp_large', 'type': 'function'}        128           0.021748
#                                                   256           0.176072
#                                                   512           1.638023
#                                                   1024         17.957571
#                                                   2048        161.343488
#                                                   4096       1308.997267
# {'name': 'correctness_check', 'type': 'function'} 128           0.022043
#                                                   256           0.177356
#                                                   512           1.645814
#                                                   1024         16.870409
#                                                   2048        161.630269
#                                                   4096       1308.476825
# {'name': 'data_init', 'type': 'function'}         128           0.000629
#                                                   256           0.002410
#                                                   512           0.012849
#                                                   1024          0.037916
#                                                   2048          0.150541
#                                                   4096          0.599948
#
#                                                                           name
#
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              128                     main
#                                                   256                     main
#                                                   512                     main
#                                                   1024                    main
#                                                   2048                    main
#                                                   4096                    main
# {'name': 'comp', 'type': 'function'}              128                     comp
#                                                   256                     comp
#                                                   512                     comp
#                                                   1024                    comp
#                                                   2048                    comp
#                                                   4096                    comp
# {'name': 'comp_large', 'type': 'function'}        128               comp_large
#                                                   256               comp_large
#                                                   512               comp_large
#                                                   1024              comp_large
#                                                   2048              comp_large
#                                                   4096              comp_large
# {'name': 'correctness_check', 'type': 'function'} 128        correctness_check
#                                                   256        correctness_check
#                                                   512        correctness_check
#                                                   1024       correctness_check
#                                                   2048       correctness_check
#                                                   4096       correctness_check
# {'name': 'data_init', 'type': 'function'}         128                data_init
#                                                   256                data_init
#                                                   512                data_init
#                                                   1024               data_init
#                                                   2048               data_init
#                                                   4096               data_init
# 1  thickets created...
# {1: <thicket.thicket.Thicket object at 0x00000256E98DC9D0>}
#                                                               1  \
#                                                             nid
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              128         1
#                                                   256         1
#                                                   512         1
#                                                   1024        1
#                                                   2048        1
#                                                   4096        1
# {'name': 'comp', 'type': 'function'}              128         3
#                                                   256         3
#                                                   512         3
#                                                   1024        3
#                                                   2048        3
#                                                   4096        3
# {'name': 'comp_large', 'type': 'function'}        128         4
#                                                   256         4
#                                                   512         4
#                                                   1024        4
#                                                   2048        4
#                                                   4096        4
# {'name': 'correctness_check', 'type': 'function'} 128         5
#                                                   256         5
#                                                   512         5
#                                                   1024        5
#                                                   2048        5
#                                                   4096        5
# {'name': 'data_init', 'type': 'function'}         128         2
#                                                   256         2
#                                                   512         2
#                                                   1024        2
#                                                   2048        2
#                                                   4096        2
#
#                                                                             \
#                                                               spot.channel
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              128        regionprofile
#                                                   256        regionprofile
#                                                   512        regionprofile
#                                                   1024       regionprofile
#                                                   2048       regionprofile
#                                                   4096       regionprofile
# {'name': 'comp', 'type': 'function'}              128        regionprofile
#                                                   256        regionprofile
#                                                   512        regionprofile
#                                                   1024       regionprofile
#                                                   2048       regionprofile
#                                                   4096       regionprofile
# {'name': 'comp_large', 'type': 'function'}        128        regionprofile
#                                                   256        regionprofile
#                                                   512        regionprofile
#                                                   1024       regionprofile
#                                                   2048       regionprofile
#                                                   4096       regionprofile
# {'name': 'correctness_check', 'type': 'function'} 128        regionprofile
#                                                   256        regionprofile
#                                                   512        regionprofile
#                                                   1024       regionprofile
#                                                   2048       regionprofile
#                                                   4096       regionprofile
# {'name': 'data_init', 'type': 'function'}         128        regionprofile
#                                                   256        regionprofile
#                                                   512        regionprofile
#                                                   1024       regionprofile
#                                                   2048       regionprofile
#                                                   4096       regionprofile
#
#                                                                            \
#                                                             Min time/rank
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              128            0.045242
#                                                   256            0.343284
#                                                   512            2.828918
#                                                   1024          22.501610
#                                                   2048         186.112122
#                                                   4096        1595.665294
# {'name': 'comp', 'type': 'function'}              128            0.021786
#                                                   256            0.161605
#                                                   512            1.163119
#                                                   1024           8.235042
#                                                   2048          58.361250
#                                                   4096         410.807558
# {'name': 'comp_large', 'type': 'function'}        128            0.021759
#                                                   256            0.161569
#                                                   512            1.163063
#                                                   1024           8.234958
#                                                   2048          58.361162
#                                                   4096         410.807462
# {'name': 'correctness_check', 'type': 'function'} 128            0.022169
#                                                   256            0.178366
#                                                   512            1.654302
#                                                   1024          14.219509
#                                                   2048         127.573371
#                                                   4096        1184.151335
# {'name': 'data_init', 'type': 'function'}         128            0.000625
#                                                   256            0.002379
#                                                   512            0.009473
#                                                   1024           0.037862
#                                                   2048           0.150724
#                                                   4096           0.601498
#
#                                                                            \
#                                                             Max time/rank
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              128            0.045242
#                                                   256            0.343284
#                                                   512            2.828918
#                                                   1024          22.501610
#                                                   2048         186.112122
#                                                   4096        1595.665294
# {'name': 'comp', 'type': 'function'}              128            0.021786
#                                                   256            0.161605
#                                                   512            1.163119
#                                                   1024           8.235042
#                                                   2048          58.361250
#                                                   4096         410.807558
# {'name': 'comp_large', 'type': 'function'}        128            0.021759
#                                                   256            0.161569
#                                                   512            1.163063
#                                                   1024           8.234958
#                                                   2048          58.361162
#                                                   4096         410.807462
# {'name': 'correctness_check', 'type': 'function'} 128            0.022169
#                                                   256            0.178366
#                                                   512            1.654302
#                                                   1024          14.219509
#                                                   2048         127.573371
#                                                   4096        1184.151335
# {'name': 'data_init', 'type': 'function'}         128            0.000625
#                                                   256            0.002379
#                                                   512            0.009473
#                                                   1024           0.037862
#                                                   2048           0.150724
#                                                   4096           0.601498
#
#                                                                            \
#                                                             Avg time/rank
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              128            0.045242
#                                                   256            0.343284
#                                                   512            2.828918
#                                                   1024          22.501610
#                                                   2048         186.112122
#                                                   4096        1595.665294
# {'name': 'comp', 'type': 'function'}              128            0.021786
#                                                   256            0.161605
#                                                   512            1.163119
#                                                   1024           8.235042
#                                                   2048          58.361250
#                                                   4096         410.807558
# {'name': 'comp_large', 'type': 'function'}        128            0.021759
#                                                   256            0.161569
#                                                   512            1.163063
#                                                   1024           8.234958
#                                                   2048          58.361162
#                                                   4096         410.807462
# {'name': 'correctness_check', 'type': 'function'} 128            0.022169
#                                                   256            0.178366
#                                                   512            1.654302
#                                                   1024          14.219509
#                                                   2048         127.573371
#                                                   4096        1184.151335
# {'name': 'data_init', 'type': 'function'}         128            0.000625
#                                                   256            0.002379
#                                                   512            0.009473
#                                                   1024           0.037862
#                                                   2048           0.150724
#                                                   4096           0.601498
#
#                                                                           \
#                                                               Total time
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              128           0.045242
#                                                   256           0.343284
#                                                   512           2.828918
#                                                   1024         22.501610
#                                                   2048        186.112122
#                                                   4096       1595.665294
# {'name': 'comp', 'type': 'function'}              128           0.021786
#                                                   256           0.161605
#                                                   512           1.163119
#                                                   1024          8.235042
#                                                   2048         58.361250
#                                                   4096        410.807558
# {'name': 'comp_large', 'type': 'function'}        128           0.021759
#                                                   256           0.161569
#                                                   512           1.163063
#                                                   1024          8.234958
#                                                   2048         58.361162
#                                                   4096        410.807462
# {'name': 'correctness_check', 'type': 'function'} 128           0.022169
#                                                   256           0.178366
#                                                   512           1.654302
#                                                   1024         14.219509
#                                                   2048        127.573371
#                                                   4096       1184.151335
# {'name': 'data_init', 'type': 'function'}         128           0.000625
#                                                   256           0.002379
#                                                   512           0.009473
#                                                   1024          0.037862
#                                                   2048          0.150724
#                                                   4096          0.601498
#
#                                                                        \
#                                                              Retiring
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              128        0.299214
#                                                   256        0.332112
#                                                   512        0.261548
#                                                   1024       0.231860
#                                                   2048       0.218205
#                                                   4096       0.214811
# {'name': 'comp', 'type': 'function'}              128        0.340465
#                                                   256        0.250601
#                                                   512        0.159987
#                                                   1024       0.126101
#                                                   2048       0.122094
#                                                   4096       0.103317
# {'name': 'comp_large', 'type': 'function'}        128        0.776448
#                                                   256        0.769536
#                                                   512        0.769328
#                                                   1024       0.773091
#                                                   2048       0.769935
#                                                   4096       0.769547
# {'name': 'correctness_check', 'type': 'function'} 128        0.769837
#                                                   256        0.757868
#                                                   512        0.651440
#                                                   1024       0.604274
#                                                   2048       0.538852
#                                                   4096       0.463832
# {'name': 'data_init', 'type': 'function'}         128        0.786617
#                                                   256        0.810351
#                                                   512        0.810803
#                                                   1024       0.813770
#                                                   2048       0.813273
#                                                   4096       0.814978
#
#                                                                            \
#                                                             Backend bound
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              128            0.214611
#                                                   256            0.249831
#                                                   512            0.286591
#                                                   1024           0.371489
#                                                   2048           0.414788
#                                                   4096           0.476127
# {'name': 'comp', 'type': 'function'}              128            0.104029
#                                                   256            0.098003
#                                                   512            0.117910
#                                                   1024           0.073295
#                                                   2048           0.132416
#                                                   4096           0.123207
# {'name': 'comp_large', 'type': 'function'}        128            0.020392
#                                                   256            0.025632
#                                                   512            0.025711
#                                                   1024           0.022947
#                                                   2048           0.025745
#                                                   4096           0.025579
# {'name': 'correctness_check', 'type': 'function'} 128            0.025539
#                                                   256            0.032221
#                                                   512            0.097295
#                                                   1024           0.151430
#                                                   2048           0.217127
#                                                   4096           0.323404
# {'name': 'data_init', 'type': 'function'}         128            0.022947
#                                                   256            0.015406
#                                                   512            0.014528
#                                                   1024           0.019652
#                                                   2048           0.019860
#                                                   4096           0.019751
#
#                                                                             \
#                                                             Frontend bound
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              128             0.409749
#                                                   256             0.344807
#                                                   512             0.378913
#                                                   1024            0.310110
#                                                   2048            0.252639
#                                                   4096            0.199804
# {'name': 'comp', 'type': 'function'}              128             0.486403
#                                                   256             0.593235
#                                                   512             0.683203
#                                                   1024            0.756153
#                                                   2048            0.703339
#                                                   4096            0.740315
# {'name': 'comp_large', 'type': 'function'}        128             0.195196
#                                                   256             0.196391
#                                                   512             0.196401
#                                                   1024            0.195307
#                                                   2048            0.195734
#                                                   4096            0.196381
# {'name': 'correctness_check', 'type': 'function'} 128             0.196490
#                                                   256             0.206929
#                                                   512             0.249873
#                                                   1024            0.243685
#                                                   2048            0.243750
#                                                   4096            0.212593
# {'name': 'data_init', 'type': 'function'}         128             0.162706
#                                                   256             0.149683
#                                                   512             0.151712
#                                                   1024            0.144664
#                                                   2048            0.145370
#                                                   4096            0.144512
#
#                                                                              \
#                                                             Bad speculation
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              128              0.076425
#                                                   256              0.073250
#                                                   512              0.072948
#                                                   1024             0.086542
#                                                   2048             0.114368
#                                                   4096             0.109258
# {'name': 'comp', 'type': 'function'}              128              0.069103
#                                                   256              0.058161
#                                                   512              0.038900
#                                                   1024             0.044450
#                                                   2048             0.042152
#                                                   4096             0.033161
# {'name': 'comp_large', 'type': 'function'}        128              0.007964
#                                                   256              0.008441
#                                                   512              0.008560
#                                                   1024             0.008655
#                                                   2048             0.008586
#                                                   4096             0.008493
# {'name': 'correctness_check', 'type': 'function'} 128              0.008134
#                                                   256              0.002982
#                                                   512              0.001392
#                                                   1024             0.000612
#                                                   2048             0.000271
#                                                   4096             0.000171
# {'name': 'data_init', 'type': 'function'}         128              0.027730
#                                                   256              0.024560
#                                                   512              0.022958
#                                                   1024             0.021913
#                                                   2048             0.021497
#                                                   4096             0.020759
#
#                                                                           name
#
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              128                     main
#                                                   256                     main
#                                                   512                     main
#                                                   1024                    main
#                                                   2048                    main
#                                                   4096                    main
# {'name': 'comp', 'type': 'function'}              128                     comp
#                                                   256                     comp
#                                                   512                     comp
#                                                   1024                    comp
#                                                   2048                    comp
#                                                   4096                    comp
# {'name': 'comp_large', 'type': 'function'}        128               comp_large
#                                                   256               comp_large
#                                                   512               comp_large
#                                                   1024              comp_large
#                                                   2048              comp_large
#                                                   4096              comp_large
# {'name': 'correctness_check', 'type': 'function'} 128        correctness_check
#                                                   256        correctness_check
#                                                   512        correctness_check
#                                                   1024       correctness_check
#                                                   2048       correctness_check
#                                                   4096       correctness_check
# {'name': 'data_init', 'type': 'function'}         128                data_init
#                                                   256                data_init
#                                                   512                data_init
#                                                   1024               data_init
#                                                   2048               data_init
#                                                   4096               data_init
#                                                               1  \
#                                                             nid
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              128         1
#                                                   256         1
#                                                   512         1
#                                                   1024        1
#                                                   2048        1
#                                                   4096        1
# {'name': 'comp', 'type': 'function'}              128         3
#                                                   256         3
#                                                   512         3
#                                                   1024        3
#                                                   2048        3
#                                                   4096        3
# {'name': 'comp_large', 'type': 'function'}        128         4
#                                                   256         4
#                                                   512         4
#                                                   1024        4
#                                                   2048        4
#                                                   4096        4
# {'name': 'correctness_check', 'type': 'function'} 128         5
#                                                   256         5
#                                                   512         5
#                                                   1024        5
#                                                   2048        5
#                                                   4096        5
# {'name': 'data_init', 'type': 'function'}         128         2
#                                                   256         2
#                                                   512         2
#                                                   1024        2
#                                                   2048        2
#                                                   4096        2
#
#                                                                             \
#                                                               spot.channel
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              128        regionprofile
#                                                   256        regionprofile
#                                                   512        regionprofile
#                                                   1024       regionprofile
#                                                   2048       regionprofile
#                                                   4096       regionprofile
# {'name': 'comp', 'type': 'function'}              128        regionprofile
#                                                   256        regionprofile
#                                                   512        regionprofile
#                                                   1024       regionprofile
#                                                   2048       regionprofile
#                                                   4096       regionprofile
# {'name': 'comp_large', 'type': 'function'}        128        regionprofile
#                                                   256        regionprofile
#                                                   512        regionprofile
#                                                   1024       regionprofile
#                                                   2048       regionprofile
#                                                   4096       regionprofile
# {'name': 'correctness_check', 'type': 'function'} 128        regionprofile
#                                                   256        regionprofile
#                                                   512        regionprofile
#                                                   1024       regionprofile
#                                                   2048       regionprofile
#                                                   4096       regionprofile
# {'name': 'data_init', 'type': 'function'}         128        regionprofile
#                                                   256        regionprofile
#                                                   512        regionprofile
#                                                   1024       regionprofile
#                                                   2048       regionprofile
#                                                   4096       regionprofile
#
#                                                                            \
#                                                             Min time/rank
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              128            0.045358
#                                                   256            0.357011
#                                                   512            3.300747
#                                                   1024          34.874304
#                                                   2048         323.149891
#                                                   4096        2619.881903
# {'name': 'comp', 'type': 'function'}              128            0.021761
#                                                   256            0.176096
#                                                   512            1.638055
#                                                   1024          17.957615
#                                                   2048         161.343535
#                                                   4096        1309.023555
# {'name': 'comp_large', 'type': 'function'}        128            0.021748
#                                                   256            0.176072
#                                                   512            1.638023
#                                                   1024          17.957571
#                                                   2048         161.343488
#                                                   4096        1308.997267
# {'name': 'correctness_check', 'type': 'function'} 128            0.022043
#                                                   256            0.177356
#                                                   512            1.645814
#                                                   1024          16.870409
#                                                   2048         161.630269
#                                                   4096        1308.476825
# {'name': 'data_init', 'type': 'function'}         128            0.000629
#                                                   256            0.002410
#                                                   512            0.012849
#                                                   1024           0.037916
#                                                   2048           0.150541
#                                                   4096           0.599948
#
#                                                                            \
#                                                             Max time/rank
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              128            0.045358
#                                                   256            0.357011
#                                                   512            3.300747
#                                                   1024          34.874304
#                                                   2048         323.149891
#                                                   4096        2619.881903
# {'name': 'comp', 'type': 'function'}              128            0.021761
#                                                   256            0.176096
#                                                   512            1.638055
#                                                   1024          17.957615
#                                                   2048         161.343535
#                                                   4096        1309.023555
# {'name': 'comp_large', 'type': 'function'}        128            0.021748
#                                                   256            0.176072
#                                                   512            1.638023
#                                                   1024          17.957571
#                                                   2048         161.343488
#                                                   4096        1308.997267
# {'name': 'correctness_check', 'type': 'function'} 128            0.022043
#                                                   256            0.177356
#                                                   512            1.645814
#                                                   1024          16.870409
#                                                   2048         161.630269
#                                                   4096        1308.476825
# {'name': 'data_init', 'type': 'function'}         128            0.000629
#                                                   256            0.002410
#                                                   512            0.012849
#                                                   1024           0.037916
#                                                   2048           0.150541
#                                                   4096           0.599948
#
#                                                                            \
#                                                             Avg time/rank
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              128            0.045358
#                                                   256            0.357011
#                                                   512            3.300747
#                                                   1024          34.874304
#                                                   2048         323.149891
#                                                   4096        2619.881903
# {'name': 'comp', 'type': 'function'}              128            0.021761
#                                                   256            0.176096
#                                                   512            1.638055
#                                                   1024          17.957615
#                                                   2048         161.343535
#                                                   4096        1309.023555
# {'name': 'comp_large', 'type': 'function'}        128            0.021748
#                                                   256            0.176072
#                                                   512            1.638023
#                                                   1024          17.957571
#                                                   2048         161.343488
#                                                   4096        1308.997267
# {'name': 'correctness_check', 'type': 'function'} 128            0.022043
#                                                   256            0.177356
#                                                   512            1.645814
#                                                   1024          16.870409
#                                                   2048         161.630269
#                                                   4096        1308.476825
# {'name': 'data_init', 'type': 'function'}         128            0.000629
#                                                   256            0.002410
#                                                   512            0.012849
#                                                   1024           0.037916
#                                                   2048           0.150541
#                                                   4096           0.599948
#
#                                                                           \
#                                                               Total time
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              128           0.045358
#                                                   256           0.357011
#                                                   512           3.300747
#                                                   1024         34.874304
#                                                   2048        323.149891
#                                                   4096       2619.881903
# {'name': 'comp', 'type': 'function'}              128           0.021761
#                                                   256           0.176096
#                                                   512           1.638055
#                                                   1024         17.957615
#                                                   2048        161.343535
#                                                   4096       1309.023555
# {'name': 'comp_large', 'type': 'function'}        128           0.021748
#                                                   256           0.176072
#                                                   512           1.638023
#                                                   1024         17.957571
#                                                   2048        161.343488
#                                                   4096       1308.997267
# {'name': 'correctness_check', 'type': 'function'} 128           0.022043
#                                                   256           0.177356
#                                                   512           1.645814
#                                                   1024         16.870409
#                                                   2048        161.630269
#                                                   4096       1308.476825
# {'name': 'data_init', 'type': 'function'}         128           0.000629
#                                                   256           0.002410
#                                                   512           0.012849
#                                                   1024          0.037916
#                                                   2048          0.150541
#                                                   4096          0.599948
#
#                                                                           name
#
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              128                     main
#                                                   256                     main
#                                                   512                     main
#                                                   1024                    main
#                                                   2048                    main
#                                                   4096                    main
# {'name': 'comp', 'type': 'function'}              128                     comp
#                                                   256                     comp
#                                                   512                     comp
#                                                   1024                    comp
#                                                   2048                    comp
#                                                   4096                    comp
# {'name': 'comp_large', 'type': 'function'}        128               comp_large
#                                                   256               comp_large
#                                                   512               comp_large
#                                                   1024              comp_large
#                                                   2048              comp_large
#                                                   4096              comp_large
# {'name': 'correctness_check', 'type': 'function'} 128        correctness_check
#                                                   256        correctness_check
#                                                   512        correctness_check
#                                                   1024       correctness_check
#                                                   2048       correctness_check
#                                                   4096       correctness_check
# {'name': 'data_init', 'type': 'function'}         128                data_init
#                                                   256                data_init
#                                                   512                data_init
#                                                   1024               data_init
#                                                   2048               data_init
#                                                   4096               data_init

# %% [markdown]
# Compose these 3 groups column-wise to get a holistic view of the data

# %% [markdown]
# Perform pandas operations to get the table in a desirable format for plotting

# %%
# Drop unwanted columns
array = [("node","")]
for i in process_cols:
    # comment out the one you wnat to plot
    array.append((i,"nid"))
    array.append((i,"spot.channel"))
    array.append((i,"Min time/rank"))
    array.append((i,"Max time/rank"))
    # array.append((i,"Avg time/rank"))
    array.append((i,"Total time"))

df_linear = df_linear.reset_index().drop(array, axis=1)
df_linear = df_linear.rename({("name", ""): "name", ("InputSize", ""): "InputSize"}).set_index(["name", "InputSize"])

df_strassen = df_strassen.reset_index().drop(array, axis=1)
df_strassen = df_strassen.rename({("name", ""): "name", ("InputSize", ""): "InputSize"}).set_index(["name", "InputSize"])
df_strassen = df_strassen.drop([(1, 'Retiring'), (1, 'Backend bound'), (1, 'Frontend bound'), (1, 'Bad speculation')])

# now grab actual values
df_linear = df_linear.loc['main']
df_strassen = df_strassen.loc['main']

df_linear
# Out:
#                       1
#           Avg time/rank
# InputSize
# 128            0.045358
# 256            0.357011
# 512            3.300747
# 1024          34.874304
# 2048         323.149891
# 4096        2619.881903

# %%
df_strassen
# Out:
#                       1
#           Avg time/rank  Retiring Backend bound Frontend bound Bad speculation
# InputSize
# 128            0.045242  0.299214      0.214611       0.409749        0.076425
# 256            0.343284  0.332112      0.249831       0.344807        0.073250
# 512            2.828918  0.261548      0.286591       0.378913        0.072948
# 1024          22.501610  0.231860      0.371489       0.310110        0.086542
# 2048         186.112122  0.218205      0.414788       0.252639        0.114368
# 4096        1595.665294  0.214811      0.476127       0.199804        0.109258

# %%
# Plot stuff!
fig, ax = plt.subplots()
ax.plot(df_linear, label='Linear')
ax.plot(df_strassen, label='Strassen')
ax.set_xlabel("Input Size")
ax.set_ylabel("Time (s)")
ax.set_title("Linear vs Strassen")
ax.legend()

# %%
# import matplotlib.pyplot as plt

# # Assuming your DataFrame is named 'df'
# df = ctk.dataframe

# # Define the matrix sizes you want to plot
# matrix_sizes = [128, 256, 512, 1024, 2048, 4096]

# # Define the communication and computation data series
# comm = ["barrier", "bcast", "gather", "scatter"]
# comp = ["comp_large", "data_init", "correctness"]

# # Loop through matrix sizes and communication data series
# for j, data_series in enumerate(comm):
#     for i, matrix_size in enumerate(matrix_sizes):
#         plt.figure(figsize=(10, 5))  # Create a new figure for each plot
#         ax = plt.gca()
#         data = df.loc[(data_series, matrix_size), :]
#         data.index = data.index.droplevel(1)  # Remove the first level of the MultiIndex
#         data.plot(ax=ax, title=f'Matrix Size: {matrix_size}, Comm: {data_series}')
#         ax.set_xlabel("num_procs")
#         ax.set_ylabel("Time (seconds)")
#         plt.show()

# # Loop through matrix sizes and computation data series
# for j, data_series in enumerate(comp):
#     for i, matrix_size in enumerate(matrix_sizes):
#         plt.figure(figsize=(10, 5))  # Create a new figure for each plot
#         ax = plt.gca()
#         data = df.loc[(data_series, matrix_size), :]
#         data.index = data.index.droplevel(1)  # Remove the first level of the MultiIndex
#         data.plot(ax=ax, title=f'Matrix Size: {matrix_size}, Comp: {data_series}')
#         ax.set_xlabel("num_procs")
#         ax.set_ylabel("Time (seconds)")
#         plt.show()

# %%
# Define common variables
function_names = set(ctk.dataframe.index.get_level_values("name"))
threads = sorted(list(set(ctk.dataframe.index.get_level_values("num_procs"))))
matrix_sizes = sorted(ctk.dataframe.columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\steve\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\multi.py:1555, in MultiIndex._get_level_number(self, level)
#    1554 try:
# -> 1555     level = self.names.index(level)
#    1556 except ValueError as err:
#
# ValueError: 'name' is not in list
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\steve\OneDrive\Documents\Coding\435Project\jupyter\testlinear.ipynb Cell 11 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/steve/OneDrive/Documents/Coding/435Project/jupyter/testlinear.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> # Define common variables
# ----> <a href='vscode-notebook-cell:/c%3A/Users/steve/OneDrive/Documents/Coding/435Project/jupyter/testlinear.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> function_names = set(ctk.dataframe.index.get_level_values("name"))
#       <a href='vscode-notebook-cell:/c%3A/Users/steve/OneDrive/Documents/Coding/435Project/jupyter/testlinear.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> threads = sorted(list(set(ctk.dataframe.index.get_level_values("num_procs"))))
#       <a href='vscode-notebook-cell:/c%3A/Users/steve/OneDrive/Documents/Coding/435Project/jupyter/testlinear.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a> matrix_sizes = sorted(ctk.dataframe.columns.tolist())
#
# File c:\Users\steve\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\multi.py:1723, in MultiIndex.get_level_values(self, level)
#    1675 def get_level_values(self, level):
#    1676     """
#    1677     Return vector of label values for requested level.
#    1678
#    (...)
#    1721     Float64Index([1.0, nan, 2.0], dtype='float64')
#    1722     """
# -> 1723     level = self._get_level_number(level)
#    1724     values = self._get_level_values(level)
#    1725     return values
#
# File c:\Users\steve\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\multi.py:1558, in MultiIndex._get_level_number(self, level)
#    1556 except ValueError as err:
#    1557     if not is_integer(level):
# -> 1558         raise KeyError(f"Level {level} not found") from err
#    1559     elif level < 0:
#    1560         level += self.nlevels
#
# KeyError: 'Level name not found'

# %% [markdown]
# # Plotting

# %% [markdown]
# ### Option 1
# Use `pandas.DataFrame.plot` to automatically interface with matplotlib

# %%
def plot_pandas(df, title, xlabel, ylabel, loglog):
    plot = df.plot(kind="line", 
        marker='o', 
        title=title, 
        xlabel=xlabel,
        ylabel=ylabel, 
        grid=True,
        loglog=loglog
    )
    return plot

# %% [markdown]
# ### Option 2
# Use `matplotlib.pyplot` directly for more fine-grained control. Specifically for our case we can change the x axis scaling from base 10 to base 2.

# %%
def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    ax.plot(
        df,
        marker='o',
    )
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(matrix_sizes)
    plt.grid(True)
    plt.yscale("log", base=10)
    plt.xscale("log", base=2)
    plt.xticks(threads)
    plt.show()
    return fig, ax

# %% [markdown]
# # Examples

# %% [markdown]
# ## time

# %%
ctk.dataframe.loc["main"]
# Out:
#                       4                                           \
#           Min time/rank Max time/rank Avg time/rank   Total time
# InputSize
# 128            0.392027      0.398540      0.393913     1.575651
# 256            0.346411      0.400129      0.360285     1.441141
# 512            0.500207      0.958925      0.615386     2.461545
# 1024           1.937511      7.917518      3.432799    13.731198
# 2048          16.257582     80.443053     32.304383   129.217530
# 4096         328.697990   1675.564007    665.414500  2661.657998
#
#                                          8                              \
#           Variance time/rank Min time/rank Max time/rank Avg time/rank
# InputSize
# 128                 0.000007      0.433096      0.440360      0.434221
# 256                 0.000529      0.492410      0.554987      0.503490
# 512                 0.039340      0.529886      1.233589      0.620466
# 1024                6.704234      1.325889      7.550431      2.105368
# 2048              772.443856      8.460777     69.807645     16.129681
# 4096           340134.008948    179.716693   1563.045031    352.633664
#
#                                                      16                \
#             Total time Variance time/rank Min time/rank Max time/rank
# InputSize
# 128           3.473769           0.000005      6.131866      9.241619
# 256           4.027923           0.000395      0.508943      0.568770
# 512           4.963731           0.053707      0.520784      1.136749
# 1024         16.842943           4.235534      0.951594      6.832092
# 2048        129.037449         411.617690      4.591423     65.259147
# 4096       2821.069309      209299.382431     94.743396   1454.893124
#
#                                                                    32  \
#           Avg time/rank   Total time Variance time/rank Min time/rank
# InputSize
# 128            7.685408   122.966527           2.398687      6.152744
# 256            0.518767     8.300279           0.000184      0.574143
# 512            0.564259     9.028137           0.021859      0.522779
# 1024           1.323841    21.181450           2.022738      0.701745
# 2048           8.386800   134.188794         215.630935      2.819830
# 4096         179.756225  2876.099606      108398.274082     45.091347
#
#                                                                        \
#           Max time/rank Avg time/rank   Total time Variance time/rank
# InputSize
# 128            9.262938      6.933099   221.859167           1.797111
# 256            0.643461      0.589362    18.859579           0.000127
# 512            1.005280      0.548887    17.564379           0.006770
# 1024           7.764880      0.928738    29.719625           1.507534
# 2048          66.892633      5.492441   175.758118         121.681125
# 4096        1445.773181     88.866504  2843.728124       59393.410687
#
#                      64                                           \
#           Min time/rank Max time/rank Avg time/rank   Total time
# InputSize
# 128            6.139745      9.087473      6.514431   416.923586
# 256            3.180303      3.679889      3.591665   229.866588
# 512            0.460709      1.103177      0.518809    33.203748
# 1024          19.128636     29.219222     22.336157  1429.514063
# 2048           2.269738     62.094665      3.961659   253.546177
# 4096          23.617032   1422.557660     45.483347  2910.934204
#
#                                        128                              \
#           Variance time/rank Min time/rank Max time/rank Avg time/rank
# InputSize
# 128                 0.938400      6.373715      8.211155      6.629711
# 256                 0.023816      3.376828      4.015285      3.866789
# 512                 0.005703      1.346687      2.278765      1.380882
# 1024                3.853780     11.930076     24.778810     12.379053
# 2048               53.681422      3.731073    129.566792      5.432938
# 4096            30100.534364     32.456763   2572.727139     53.529805
#
#
#             Total time Variance time/rank
# InputSize
# 128         848.603060           0.350501
# 256         494.948953           0.016210
# 512         176.752954           0.006439
# 1024       1584.518836           1.227128
# 2048        695.416108         121.366908
# 4096       6851.814990       49975.918387

# %%
for name in function_names:
    plot_pandas(
        df=ctk.dataframe.loc[name],
        title=name,
        xlabel="Threads",
        ylabel="Time (seconds)",
        loglog=True
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-700f45f671fa> in <module>
# ----> 1 for name in function_names:
#       2     plot_pandas(
#       3         df=ctk.dataframe.loc[name],
#       4         title=name,
#       5         xlabel="Threads",
#
# NameError: name 'function_names' is not defined

# %%
for name in function_names:
    plot_mpl(
        df=ctk.dataframe.loc[name],
        title=name,
        xlabel="num_procs",
        ylabel="Time (seconds)",
    )

# %% [markdown]
# ## Speedup

# %%
speedup_df = ctk.dataframe.loc[(slice(None),1), :].reset_index().drop("threads", axis=1).set_index("name")/ctk.dataframe

for name in function_names:
    plot_pandas(
        df=speedup_df.loc[name],
        title=f"{name}: thread-1/thread-N",
        xlabel="Threads",
        ylabel="Speedup",
        loglog=False
    )
